# %%
income = 100000

# %%
def calculate_val(income: int , percent_val: int):
    return (income * percent_val) //100

# %%
def  growth(income,percent_val=25):
    value = calculate_val(income,percent_val)
    print(value)
    return value

# %%
def stability(income, percent_val = 15):
    value = calculate_val(income,percent_val)
    print(value)
    return value

# %%
def essential(income, percent_val = 50):
    value = calculate_val(income,percent_val)
    print(value)
    return value

# %%
def reward(income, percent_val=10):
    value = calculate_val(income,percent_val)
    print(value)
    return value

# %%
essential(income)
reward(income)
stability(income)
growth(income)
# Out:
# 50000
# 10000
# 15000
# 25000
# 25000

# %%
def monthly_expense():
    expanses = {}
    features = ["Rent","Electricity Bill","gas","Water Bill","Internet Bills","Groceries","Transportation cost","Health insurance","Life insurance","Childcare and education","Personal care"]
    for feature in features:
        expanses[feature] = int(input(f'{feature} Amount: '))
    return expanses

# %%
a = monthly_expense()
